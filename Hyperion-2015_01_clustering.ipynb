# %% [markdown]
# # Hyperion fire after AGU - January 2015

# %% [markdown]
# This notebook contains the code to generate the output used in my AGU poster 2014.

# %% [markdown]
# ## 1. Load prerequisites, filepaths, libraries

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline   
import os.path
import random
import json
import h5py
import pickle
import itertools
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from pygaarst import raster
from pygaarst import landsatutils as l
from pygaarst import hyperionutils as hyp
from pygaarst import irutils as ir
from pygaarst import rasterhelpers as rh
from pygaarst import geomutils as gu
import brewer2mpl    # better color schemes

# %% [markdown]
# Set up plot options.

# %%
bmap = brewer2mpl.get_map('Set1', 'qualitative', 7)
colors = bmap.mpl_colors
mpl.rcParams['axes.color_cycle'] = colors
mpl.rcParams.update({'font.size': 24, 'font.family': 'Calibri'})

# %% [markdown]
# Directory and file names.

# %%
basedir = "/Volumes/SCIENCE/Fire/DATA_BY_PROJECT/HyspIRI_Prep_2014/"
outdir = "/Volumes/SCIENCE/Fire/DATA_BY_PROJECT/HyspIRI_Prep_2014/visual/tmp/"
outgis = "GIS"
dir_2004 = "2004Boundary"
dir_2009 = "2009WoodRiver"
hypscene_2004 = "EO1H0690142004201110PX"
aliscene_2004 = "EO1A0690142004201110PX"
landsatscene_2004 = "LE70690142004201EDC01"
hypscene_2009 = "EO1H0690142009214110KF"
aliscene_2009 = "EO1A0690142009214110KF"
landsatscene_2009 = "LT50680152009215GLC00"  # There is also a simultaneous L7 scene, LE70690152009214EDC00, but it's stripey

# %% [markdown]
# Select year to work on:

# %%
fireyear = 2004
if fireyear == 2004:
    hypsc = raster.Hyperionscene(os.path.join(basedir, dir_2004, hypscene_2004))
    hypsc.infix = '_CLIP'
    filedir = dir_2004
    firename = 'boundary'
    figdim = (15, 19)
    colbarpos = [0.125, 0.2, 0.725, 0.025]
elif fireyear == 2009:
    hypsc = raster.Hyperionscene(os.path.join(basedir, dir_2009, hypscene_2009))
    hypsc.infix = '_CLIP'
    filedir = dir_2009
    firename = 'woodriver'
    figdim = (15, 25)
    colbarpos = [0.125, 0.125, 0.74, 0.02]
else:
    raise Exception("Fireyear not implemented.")

# %% [markdown]
# ### Reload, if necessary

# %% [markdown]
# The `pygaarst` library is being developed as this code is written. Therefore, reloading the modules is frequently necessary.

# %%
reload(raster)
reload(ir)
reload(l)
reload(hyp)
reload(rh)
# Out:
# <module 'pygaarst.rasterhelpers' from '/Users/chris/Dropbox/research/pygaarst/pygaarst/rasterhelpers.pyc'>

# %% [markdown]
# ### Save Hyperion band designations to text file for external use

# %%
SAVEOUT = False

if SAVEOUT: 
    ofn = os.path.join(outdir, "hyp_calib_bandnames.txt")
    out = '\n'.join(hypsc.calibratedbands.astype('str'))
    with open(ofn, 'w') as ofh:
        ofh.write(out)

# %%
SAVEOUT = False

if SAVEOUT: 
    ofn = os.path.join(outdir, "hyp_calib_wave_nm.txt")
    out = '\n'.join(hypsc.calibratedwavelength_nm.astype('str'))
    with open(ofn, 'w') as ofh:
        ofh.write(out)

# %% [markdown]
# ## 2. Load data: radiance, fire and buffer candidate pixels

# %% [markdown]
# We want to work on a SWIR band for rough fire detection via radiance thresholding. Ideally, it should be determined by being low in noise and strong in signal. This is the subject of a different notebook. Here, we just quickly compare two bands with respect to their basic statistical properties.

# %%
bandnum = 210

b220 = hypsc.band220
b210 = hypsc.band210

# %%
med = np.median(b220.radiance.flatten())
mean = np.mean(b220.radiance.flatten())
mn = np.amin(b220.radiance.flatten())
mx = np.amax(b220.radiance.flatten())
std = np.std(b220.radiance.flatten())
print("minimum: {0}, maximum: {1:.3f}, mean: {2:.3f}, median: {3:.3f}, standard dev: {4:.3f} ".format(mn, mx, mean, med, std))
# Out:
# minimum: 0.0, maximum: 409.587, mean: 0.611, median: 0.663, standard dev: 1.970

# %%
med = np.median(b210.radiance.flatten())
mean = np.mean(b210.radiance.flatten())
mn = np.amin(b210.radiance.flatten())
mx = np.amax(b210.radiance.flatten())
std = np.std(b210.radiance.flatten())
print("minimum: {0}, maximum: {1:.3f}, mean: {2:.3f}, median: {3:.3f}, standard dev: {4:.3f} ".format(mn, mx, mean, med, std))
# Out:
# minimum: 0.0, maximum: 409.587, mean: 1.066, median: 1.275, standard dev: 3.552

# %%
if bandnum == 210:
    bd = b210
elif bandnum == 220:
    bd = b220
else:
    print("Please choose suitable band number")

# %% [markdown]
# Plot the radiance map.

# %%
saveout = False

f, ax = plt.subplots(figsize=figdim)
position=f.add_axes(colbarpos)
#output = ax.pcolor(bd.radiance, cmap='hot', vmin=0, vmax=40)
output = ax.pcolor(bd.radiance, cmap='rainbow', vmin=0, vmax=40)
ax.set_title("%s %s fire Band %s, Radiance in $W / (m^2 \mu m\, sr)$" % (fireyear, firename.capitalize(), bd.band))
ax.set_aspect('equal')
ax.invert_yaxis()
ax.set_axis_off()
divider = make_axes_locatable(ax)
plt.colorbar(output, orientation='horizontal', cax=position, ticks=range(0, 75, 5))
if saveout:
    outfile = os.path.join(outdir, "rad_b%s_%s_plot.png" % (bandnum, fireyear))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %% [markdown]
# Plot in "bone" shades -- maybe better visibility?

# %%
saveout = False

f, ax = plt.subplots(figsize=figdim)
position=f.add_axes(colbarpos)
output = ax.pcolor(bd.radiance, cmap='bone', vmin=0, vmax=40)
ax.set_title("%s %s fire Band %s, Radiance in $W / (m^2 \mu m\, sr)$" % (fireyear, firename.capitalize(), bd.band))
ax.set_aspect('equal')
ax.invert_yaxis()
ax.set_axis_off()
divider = make_axes_locatable(ax)
plt.colorbar(output, orientation='horizontal', cax=position, ticks=range(0, 75, 5))
if saveout:
    outfile = os.path.join(outdir, "rad_b%s_%s_plot_bw.png" % (bandnum, fireyear))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %%
saveout = True

f, ax = plt.subplots(figsize=figdim)
position=f.add_axes(colbarpos)
output = ax.pcolor(bd.radiance, cmap='RdBu_r', vmin=0, vmax=50)
ax.set_title("%s %s fire Band %s, Radiance in $W / (m^2 \mu m\, sr)$" % (fireyear, firename.capitalize(), bd.band))
ax.set_aspect('equal')
ax.invert_yaxis()
ax.set_axis_off()
divider = make_axes_locatable(ax)
plt.colorbar(output, orientation='horizontal', cax=position, ticks=range(0, 75, 5))
if saveout:
    outfile = os.path.join(outdir, "rad_b%s_%s_plot_br.png" % (bandnum, fireyear))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %% [markdown]
# ### Make vector files

# %% [markdown]
# From now on we work in the native coordinate system of the data (UTM zone 6N). We identify the fire candidate pixels and a convex polygon that covers all of them.

# %% [markdown]
# First, section-specific modules are imported.

# %%
import fiona
from shapely.geometry import Point, MultiPoint, Polygon, mapping
from shapely.ops import cascaded_union
from descartes.patch import PolygonPatch

# %%
radthresh = 5.0  # Radiance threshold. In the SWIR, non-fire emitted and reflected radiances are much smaller. 
largebuff = 100 # in m 

i_fire, j_fire = np.where(bd.radiance > radthresh)
e_fire, n_fire = bd.ij2xy(i_fire, j_fire)
# the fire points are in the center of the pixels, while the easting and northing designate the top-left corner
e_fire += 0.5 * bd.delx
n_fire += 0.5 * bd.dely   # note that dely is negative
# Easting and northing as x and y coordinate mesh
E, N = bd._XY

# %%
# calculate fire shapes
firepoints = MultiPoint(zip(e_fire, n_fire))
hull = firepoints.convex_hull
dilated = hull.buffer(largebuff)

# %%
saveout = False

f, ax = plt.subplots(figsize=figdim)
output = ax.pcolor(E, N, np.flipud(bd.radiance), cmap='hot', vmin=0, vmax=40)
ax.set_aspect('equal')
ax.set_xlabel("UTM6N: easting")
ax.set_ylabel("UTM6N: northing")
ax.set_title("Fire pixels identified by radiance threshold in band %s: %s %s fire" % (bandnum, fireyear, firename.capitalize()))
plt.tight_layout()
patch2 = PolygonPatch(dilated, facecolor='#6699cc', edgecolor='#6699cc', alpha=0.2, zorder=2)
ax.add_patch(patch2)
for p in firepoints:
    ax.plot(p.x, p.y, 'o', color='#999999', alpha=0.7)
if saveout:
    outfile = os.path.join(outdir, "rad_b%s_%s_area_plot.png" % (bandnum, fireyear))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %% [markdown]
# Now let's make circular buffers around the points and define their union as the close-proximity vector collcetion. The result is a multipolygon object.

# %%
buffrad = 600 # in m
firecircles = [Point(eastx, northy).buffer(buffrad) for eastx, northy in zip(e_fire, n_fire)]
circbuffer = cascaded_union(firecircles)

# %% [markdown]
# Let's plot this one.

# %%
saveout = False

f, ax = plt.subplots(figsize=figdim)
output = ax.pcolor(E, N, np.flipud(bd.radiance), cmap='hot', vmin=0, vmax=40)
ax.set_aspect('equal')
ax.set_xlabel("UTM6N: easting")
ax.set_ylabel("UTM6N: northing")
plt.tight_layout()
ax.set_title("Band %s, %s %s: fire candidate pixels and 600m radius buffers with $L > 5 W / m^2 \mu m$" 
             % (bandnum, fireyear, firename.capitalize()) , y=1.03, )
for polygon in circbuffer:
    patch = PolygonPatch(polygon, facecolor='#6699cc', edgecolor='#6699cc', alpha=0.3, zorder=2)
    ax.add_patch(patch)
if saveout:
    outfile = os.path.join(outdir, "fire_circbuff_%s_b%s_plot.png" % (fireyear, bandnum))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %% [markdown]
# ### Save vectors to file

# %% [markdown]
# We need a coordinate reference system for the shapefile. We get it from the raster data object. The `fiona` module contains a function to translate it from the PROJ4 string to the mapping format that is needed.

# %%
from fiona.crs import from_string
my_crs = from_string(bd.proj4)

# %% [markdown]
# Next we need a schema. We use the simplest one.

# %% [markdown]
# Fire pixels first.

# %%
schema = { 'geometry': 'Point', 'properties': {'id': 'int'} }

# %%
outfn = os.path.join(basedir, filedir, outgis, 'firepixels_b{}_{}.shp'.format(bandnum, firename))

with fiona.open(
    outfn, "w", driver="ESRI Shapefile", crs=my_crs, schema=schema) as output:
    for idx, item in enumerate(firepoints):
        output.write({
            'geometry': mapping(item),
            'properties': {'id': idx}
        })

# %% [markdown]
# Polygons next.

# %%
schema = { 'geometry': 'Polygon', 'properties': {'id': 'int'} }

# %%
outfn = os.path.join(basedir, filedir, outgis, 'convexfirehull_b{}_{}.shp'.format(bandnum, firename))

with fiona.open(
    outfn, "w", driver="ESRI Shapefile", crs=my_crs, schema=schema) as output:
    output.write({
        'geometry': mapping(dilated),
        'properties': {'id': 0}
    })

# %%
outfn = os.path.join(basedir, filedir, outgis, 'circbuffer_b{}_{}.shp'.format(bandnum, firename))

with fiona.open(
    outfn, "w", driver="ESRI Shapefile", crs=my_crs, schema=schema) as output:
    for idx, item in enumerate(circbuffer):
        output.write({
            'geometry': mapping(item),
            'properties': {'id': idx}
        })

# %% [markdown]
# ### Make raster versions, and save to file

# %% [markdown]
# I would also like to have the file in a raster file. This should be a GeoTIFF raster of the same size as the study area file, with two values. Basically, a mask, but marking the inside of the polygons (that is, an inverted mask). I could use 1 for "in the polygon" and 0 for "not in the polygon", but for quick viewing of the file as an 8-bit unsigned integer type GeoTIFF file, it should be easier to multiply the value by 255, so that "in" is displayed as white in default settings.

# %% [markdown]
# To this end, the geometry objects corresponding to the fire points, the circular buffers and the area buffer need to be converted to array coordinates.

# %% [markdown]
# Let's define a function that turns an (x, y) coordinate pair into a (j, i) col-row index pair.

# %%
def xy2ji(xytup, geotiff):
    restup = geotiff.xy2ij(*xytup)
    return (restup[1], restup[0])

# %%
firemask = np.zeros(bd.data.shape)
firemask[bd.radiance > radthresh] = 1.

# %%
firepoints_ij_list =list(
        itertools.chain.from_iterable(
            [[xy2ji(tup, bd) for tup in point.coords[:]] 
                 for point in firepoints]))

firepoints_ij = MultiPoint(firepoints_ij_list)

# %%
circbuffer_ij = cascaded_union(
    [ Polygon([xy2ji(tup, bd) for tup in list(poly.exterior.coords)])
         for poly in circbuffer])

# %%
circbuffer_mask = gu.overlayvectors(bd.data, circbuffer_ij)
circbuffer_mask -= firemask

# %%
area_ij = [Polygon([xy2ji(tup, bd) for tup in list(dilated.exterior.coords)])]

# %%
area_mask = gu.overlayvectors(bd.data, area_ij)

# %%
f, ax = plt.subplots(figsize=figdim)
output = ax.pcolor(np.zeros(bd.data.shape), cmap='bone', vmin=0, vmax=1)
ax.set_aspect('equal')
ax.invert_yaxis()
ax.xaxis.set_ticks_position('top')
for polygon in circbuffer_ij:
    patch = PolygonPatch(polygon, facecolor='#6699cc', edgecolor='#6699cc', alpha=0.3, zorder=2)
    ax.add_patch(patch)

# %%
f, ax = plt.subplots(figsize=figdim)
output = ax.pcolor(0.5*circbuffer_mask, cmap='bone', vmin=0, vmax=1)
ax.set_aspect('equal')
ax.xaxis.set_ticks_position('top')
ax.invert_yaxis()

# %%
f, ax = plt.subplots(figsize=figdim)
output = ax.pcolor(0.5*firemask, cmap='bone', vmin=0, vmax=1)
ax.set_aspect('equal')
ax.xaxis.set_ticks_position('top')
ax.invert_yaxis()

# %%
f, ax = plt.subplots(figsize=figdim)
output = ax.pcolor(0.5*area_mask, cmap='bone', vmin=0, vmax=1)
ax.set_aspect('equal')
ax.xaxis.set_ticks_position('top')
ax.invert_yaxis()

# %%
saveout = False

f, ax = plt.subplots(figsize=figdim)
output = ax.pcolor(firemask, cmap='bone', vmin=0, vmax=1)
ax.set_title("Band %s, %s %s: fire candidate pixels with $L > 5 W / m^2 \mu m$" 
             % (bandnum, fireyear, firename.capitalize()) , y=1.03, )
ax.set_aspect('equal')
ax.invert_yaxis()
ax.xaxis.set_ticks_position('top')
plt.tight_layout()
patch2 = PolygonPatch(area_ij[0], facecolor='#6699cc', edgecolor='#6699cc', alpha=0.5, zorder=2)
ax.add_patch(patch2)
if saveout:
    outfile = os.path.join(outdir, "fire01_%s_plot.png" % fireyear)
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %%
firemask_ds = b220.clone(os.path.join(outdir, '%sfire_01.tif' % firename), firemask_ext) 
firemask_ext_ds = b220.clone(os.path.join(outdir, '%sfire_ext01.tif' % firename), firemask_ext)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5e482497d296> in <module>()
# ----> 1 firemask_ds = b220.clone(os.path.join(outdir, '%sfire_01.tif' % firename), firemask_ext)
#       2 firemask_ext_ds = b220.clone(os.path.join(outdir, '%sfire_ext01.tif' % firename), firemask_ext)
#
# NameError: name 'firemask_ext' is not defined

# %% [markdown]
# ## 3. Calculate spectra

# %% [markdown]
# ### Preparation

# %% [markdown]
# How long does it take to calculate 1 spectrum? This is mostly an I/O problem as the individual bands still reside in different data files.

# %%
# %%timeit
spec1 = hypsc.spectrum(i_fire[45], j_fire[45], bands='selected', bdsel=range(127, 224))
# Out:
# 1 loops, best of 3: 455 ms per loop

# %%
# %%timeit
spec1 = hypsc.spectrum(i_fire[45], j_fire[45])
# Out:
# 1 loops, best of 3: 911 ms per loop

# %% [markdown]
# We can save and load spectra using pickle. The variable ``specs`` is supposed to be a list or 1D array of spectra, with i and j arrays of the same length of coordinates.
#
# Some general remarks on persisting the spectra and sample points. There are various options:
# * spectra (that is, iterables of spectra) can be saved to file with the pickle module, but the drawback is that he i, j coordinate information is lost; that is acceptable for the fire candidate pixels, which are defined via an external criteron (radiance threshold)
# * if samples of coordinate pairs are taken (eg, take a sample of buffer pixels, of outside pixels...) THESE also have to be saved. This can easily be done via json. Then the actual spectra can be pickled. However, saving coordinates and spectra in two different files is a recipe for data corruption
# * the overall preferable method would be to save the whole set of arrays (covert any lists to numpay arrays first) to HDF5. ``pygaarst`` contains a function for that purpose in the ``rasterhelpers`` module. It requires numpy arrays of i and j coordinates, and spectra.

# %%
def specstopickle(outfilepath, specs):
    with open(outfilepath, "w") as sink:
        pickle.dump(specs, sink)

# %%
infilepath = os.path.join(outdir, "%s_firespecs.dat" % firename)

def specsfrompickle(filepath, hypsc, ii, jj, picklefile=True, calculate=False):
    if picklefile:
        try:        
            with open(filepath, "rU") as source:
                specs = pickle.load(source)
        except IOError, EOFError:
            calculate = True
    if (calculate or not picklefile):
        specs = [hypsc.spectrum(i, j) for i, j in itertools.izip(ii, jj)]
        if picklefile:
            specstopickle(filepath, specs)
    return specs

# %%
def specsfromhdf5(filepath, startbandidx=0):
    with h5py.File(infn, "r") as infh:
        specs = infh['spectrum'][:, startbandidx:]
        ii = infh['i_row_idx'][...]
        jj = infh['j_col_idx'][...]
        wav = infh['bandwavelenght_nm'][startbandidx:]
        bn = infh['bandname'][startbandidx:]
        return specs, ii, jj, wav, bn

# %% [markdown]
# ### Fire pixels (candidates)

# %% [markdown]
# Calculate default spectra for fire pixels. Default means only calibrated bands. How many did we get?

# %%
infn = os.path.join(outdir, "%s_firespecs.dat" % firename)
specs_fire = specsfrompickle(infn, hypsc, i_fire, j_fire)

# %%
print(len(specs_fire), len(i_fire))
print(type(specs_fire[0][0]), len(specs_fire[0]))
print(type(specs_fire), type(specs_fire[0]))
print(specs_fire[0])
# Out:
# (347, 347)
# (<type 'numpy.float32'>, 198)
# (<type 'list'>, <type 'list'>)
# [53.900002, 49.775002, 50.650002, 49.474998, 49.849998, 50.549999, 45.575001, 43.599998, 41.424999, 39.099998, 38.525002, 37.5, 36.325001, 34.875, 32.549999, 30.6, 29.424999, 28.525, 27.9, 26.275, 25.049999, 24.25, 23.225, 21.725, 21.6, 21.35, 19.450001, 21.299999, 23.375, 21.75, 25.575001, 28.5, 27.0, 19.424999, 27.75, 28.125, 26.35, 25.75, 22.15, 20.450001, 22.950001, 25.6, 25.625, 25.275, 25.025, 23.875, 20.225, 15.5, 15.8, 16.4, 12.325, 16.9, 8.1000004, 7.7249999, 8.0625, 12.7125, 16.775, 19.4375, 21.0875, 20.987499, 22.375, 21.5, 20.0, 20.65, 20.625, 19.575001, 18.525, 17.862499, 15.425, 11.8875, 4.4499998, 1.675, 3.5374999, 4.0124998, 6.0999999, 10.2375, 11.65, 11.5625, 11.55, 11.7375, 13.125, 13.925, 15.0125, 14.8875, 14.0375, 12.6875, 13.95, 14.35, 13.1625, 11.1625, 9.6499996, 7.3249998, 5.0999999, 1.975, 0.0125, 0.0125, 0.0125, 0.0125, 0.0125, 0.0125, 0.0125, 0.25, 0.3125, 0.86250001, 1.8125, 1.425, 2.125, 3.625, 5.8874998, 7.3625002, 8.3000002, 9.0874996, 9.3125, 9.6999998, 10.2125, 9.6499996, 9.6499996, 9.7749996, 9.875, 9.9125004, 10.4625, 10.4875, 10.1375, 10.525, 10.2, 10.1, 10.275, 10.1375, 9.9250002, 9.5375004, 9.2624998, 8.8249998, 8.4875002, 8.5, 7.7125001, 6.7874999, 5.4124999, 4.0500002, 1.85, 0.66250002, 0.48750001, 0.33750001, 0.0125, 0.0125, 0.1375, 0.1125, 0.0125, 0.0125, 0.0125, 0.087499999, 0.0125, 0.0125, 0.69999999, 1.175, 1.8875, 4.4250002, 6.1875, 6.0, 2.375, 2.7874999, 5.6750002, 8.3125, 7.9000001, 6.0625, 6.3375001, 7.4875002, 8.4624996, 8.9624996, 9.2375002, 9.4375, 9.0874996, 9.2875004, 9.625, 9.2124996, 9.1000004, 9.0500002, 9.3000002, 9.4125004, 8.9624996, 9.4250002, 9.6875, 9.5749998, 9.4250002, 9.25, 9.1125002, 9.1125002, 9.0749998, 8.5625, 8.8125, 8.6125002, 8.5500002, 8.3999996, 8.0124998, 8.1000004, 7.7750001, 6.8625002, 6.8000002, 7.3499999]

# %% [markdown]
# Alternative: save spectra to HDF5 file.

# %%
outfn = os.path.join(outdir, "%s_firespecs_calib.hdf5" % firename)
rh.save_hypspec_to_hdf5(outfn, hypsc, specs_fire, i_fire, j_fire)

# %% [markdown]
# ### Buffer pixels

# %% [markdown]
# Pull sample from buffer pixels (that is, not fire pixels, within buffer from fire pixels) if there is no saved data file. These represent "background" candidates. We use the circular buffer as the "buffer".

# %%
i_buffer, j_buffer = np.where(circbuffer_mask == 1)
print(len(i_buffer))
# Out:
# 22355

# %% [markdown]
# Fix seed for random number generator.

# %%
random.seed(100)

# %%
N = len(i_fire)
fn = os.path.join(outdir, "%s_circbuffersample.txt" % firename)

loadfromfile = True
savetofile = False
if loadfromfile:
    with open(fn, "rU") as source:
        for line in source:
            if line.startswith('#'):
                continue
            buffersample = json.loads(line)
else:
    i_buffer, i_buffer = np.where(firemask_ext == 0.5)
    buffersample = random.sample(zip(i_buffer, j_buffer), N)
print(buffersample)
if savetofile:
    with open(fn, "w") as sink:
        sink.write("#i and j coordinates for random sample from buffer pixels around fire candidate pixels, %s\n" % firename.capitalize())
        sink.write(json.dumps(buffersample))
# Out:
# [[164, 171], [213, 164], [291, 68], [86, 110], [297, 52], [78, 199], [294, 87], [95, 58], [164, 170], [236, 187], [172, 178], [159, 88], [196, 141], [262, 191], [252, 178], [171, 283], [203, 212], [220, 229], [202, 211], [262, 200], [86, 54], [157, 142], [235, 251], [126, 93], [208, 174], [97, 102], [268, 74], [140, 149], [136, 112], [89, 96], [157, 157], [173, 130], [75, 129], [46, 212], [217, 226], [99, 193], [279, 73], [270, 212], [237, 184], [120, 89], [123, 128], [83, 90], [176, 142], [148, 145], [143, 107], [130, 155], [108, 162], [106, 58], [227, 248], [160, 120], [183, 143], [178, 249], [185, 83], [222, 170], [151, 124], [302, 72], [114, 190], [205, 198], [202, 178], [258, 272], [299, 131], [109, 126], [73, 97], [147, 200], [50, 203], [196, 151], [204, 159], [158, 167], [82, 84], [141, 56], [151, 160], [72, 116], [101, 125], [82, 89], [180, 186], [55, 287], [220, 234], [262, 188], [193, 159], [187, 163], [176, 277], [92, 47], [226, 155], [167, 167], [146, 153], [221, 230], [118, 78], [192, 278], [197, 210], [184, 141], [96, 168], [145, 248], [38, 62], [133, 99], [161, 146], [173, 144], [173, 138], [202, 284], [155, 164], [266, 58], [198, 138], [154, 160], [221, 230], [244, 258], [108, 76], [157, 164], [201, 173], [160, 167], [164, 170], [169, 112], [177, 130], [71, 36], [116, 87], [187, 258], [198, 149], [213, 222], [139, 94], [228, 242], [156, 163], [253, 200], [102, 224], [100, 166], [111, 72], [186, 91], [149, 89], [231, 246], [202, 285], [207, 216], [161, 92], [200, 157], [270, 210], [267, 207], [246, 168], [103, 175], [100, 81], [80, 36], [224, 238], [180, 180], [161, 167], [204, 225], [283, 205], [87, 55], [166, 64], [65, 143], [254, 197], [34, 33], [151, 96], [154, 188], [155, 164], [84, 96], [147, 147], [114, 80], [251, 194], [36, 103], [159, 166], [281, 277], [162, 162], [92, 128], [40, 63], [111, 63], [154, 163], [141, 228], [202, 149], [209, 223], [152, 161], [127, 282], [79, 43], [256, 182], [66, 34], [286, 204], [159, 166], [31, 206], [295, 202], [106, 148], [267, 187], [182, 101], [123, 77], [238, 252], [129, 228], [115, 73], [148, 172], [127, 42], [110, 77], [96, 151], [85, 209], [170, 170], [157, 166], [151, 158], [95, 101], [63, 31], [95, 102], [57, 223], [92, 85], [168, 175], [186, 292], [290, 197], [168, 209], [121, 74], [125, 161], [206, 160], [159, 148], [160, 75], [138, 286], [128, 283], [94, 101], [77, 108], [93, 151], [61, 92], [237, 258], [163, 201], [273, 55], [158, 234], [156, 162], [164, 164], [95, 47], [43, 203], [143, 150], [189, 157], [150, 156], [204, 175], [184, 136], [258, 205], [164, 170], [139, 144], [146, 44], [110, 68], [161, 161], [119, 79], [150, 135], [149, 202], [144, 162], [169, 175], [107, 61], [240, 254], [80, 169], [170, 170], [230, 244], [160, 128], [157, 164], [250, 170], [185, 211], [198, 168], [99, 122], [181, 113], [203, 212], [90, 96], [128, 178], [147, 113], [67, 139], [31, 55], [102, 108], [169, 206], [199, 208], [263, 190], [91, 83], [135, 80], [133, 180], [163, 163], [97, 114], [145, 154], [40, 80], [171, 61], [183, 145], [112, 77], [175, 182], [161, 161], [83, 235], [233, 180], [126, 213], [217, 226], [208, 217], [224, 242], [252, 197], [216, 237], [112, 117], [103, 185], [217, 232], [164, 164], [228, 246], [299, 143], [221, 230], [211, 198], [75, 82], [250, 193], [153, 162], [87, 53], [129, 208], [83, 137], [153, 113], [216, 169], [161, 161], [42, 135], [158, 164], [122, 75], [110, 90], [299, 86], [186, 132], [89, 155], [248, 263], [179, 134], [40, 210], [270, 297], [199, 220], [221, 178], [265, 191], [153, 184], [153, 191], [234, 168], [82, 136], [116, 82], [202, 216], [126, 79], [104, 72], [250, 197], [100, 106], [77, 83], [66, 32], [53, 140], [160, 42], [75, 157], [254, 183], [268, 285], [58, 290], [161, 132], [165, 183], [280, 276], [92, 115], [151, 103], [143, 58], [116, 157], [222, 175], [146, 168], [208, 161], [164, 149], [97, 172], [149, 113], [271, 37], [94, 117], [87, 94], [138, 203], [122, 90], [74, 188], [228, 199], [245, 266], [267, 44], [154, 120], ...

# %% [markdown]
# Pickle results

# %%
i_buffersample = [sample[0] for sample in buffersample]
j_buffersample = [sample[1] for sample in buffersample]

# %%
fn = os.path.join(outdir, "%s_circbuffersamplespecs.dat" % firename)
specs_buffersample = specsfrompickle(fn, hypsc, i_buffersample, j_buffersample)

# %% [markdown]
# Save results to HDF5

# %%
outfn = os.path.join(outdir, "%s_circbuffersamplespecs_calib.hdf5" % firename)
rh.save_hypspec_to_hdf5(outfn, hypsc, specs_buffersample, i_buffersample, j_buffersample)

# %% [markdown]
# ### Plot some spectra

# %%
len(specs_buffersample)
# Out:
# 347

# %% [markdown]
# First some fire spectra.

# %%
specs = specs_fire
saveout = False
for idx, spec in enumerate(specs[50:55]):
    f, ax = plt.subplots(1, 1, figsize=(18, 10))
    ax.set_xlabel("Wavelength (nm)")
    ax.set_ylabel("Spectral radiance")
    ax.set_xlim(400, 2500)
    ax.set_ylim(0, 70)
    ax.set_title("%s %s fire: Spectrum for fire candidate pixel at %s, %s" % (fireyear, firename.capitalize(), i_fire[idx], j_fire[idx]))
    ax.plot(hypsc.calibratedwavelength_nm, spec, 's-', linewidth=2)  
    ax.vlines([770, 2010, 2060, 2430], [0, 0, 0, 0], [70, 70, 70, 70])
#    ax.text(1600, 54, "mod HFDI-value: %.4f" % hfdi2[i_fire[idx], j_fire[idx]])
#    ax.text(1600, 60, "CIBR-value: %.4f" % cibr[i_fire[idx], j_fire[idx]])
#    ax.text(1600, 57, "mod CIBR-value: %.4f" % cibr2[i_fire[idx], j_fire[idx]])
    if saveout:
        outfile = os.path.join(outdir, "%s_spectrum_full_%s_%s.png" % (firename, i_fire[idx], j_fire[idx]))
        plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %%
specs = specs_fire
saveout = False

f, ax = plt.subplots(1, 1, figsize=(18, 10))
ax.set_xlabel("Wavelength (nm)")
ax.set_ylabel("Spectral radiance $W / m^2 \mu m\ sr$")
ax.set_xlim(400, 2500)
ax.set_ylim(0, 70)
ax.vlines([770, 2010, 2060, 2430], [0, 0, 0, 0], [50, 50, 50, 50])
for wav in [770, 2010, 2060]:
    n, bn, w = hyp.find_nearest_hyp(wav)
    delta = 0
    if wav == 2010: delta = -150
    ax.annotate(bn, xy=(w, 60), xytext=(w+delta, 65),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
ax.annotate('2340 nm', xy=(2430, 60), xytext=(2430, 65),
        arrowprops=dict(facecolor='black', shrink=0.05),
        )
ax.set_title("%s %s fire: Spectrum for a sample of fire candidate pixels" % (fireyear, firename.capitalize()))
for idx, spec in enumerate(specs[50:55]):
    ax.plot(hypsc.calibratedwavelength_nm, spec, 's-', linewidth=3)  

if saveout:
    outfile = os.path.join(outdir, "%s_spectrum_firesamples.png" % (firename,))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %%
specs = specs_buffersample

# %%
saveout = False

f, ax = plt.subplots(1, 1, figsize=(18, 10))
ax.set_xlabel("Wavelength (nm)")
ax.set_ylabel("Spectral radiance $W / m^2 \mu m\ sr$")
ax.set_xlim(400, 2500)
ax.set_ylim(0, 70)
ax.vlines([770, 2010, 2060, 2430], [0, 0, 0, 0], [50, 50, 50, 50])
ax.set_title("%s %s fire: Spectrum for a sample of pixels adjacent to active fire" % (fireyear, firename.capitalize()))
for idx, spec in enumerate(specs[165:170]):
    ax.plot(hypsc.calibratedwavelength_nm, spec, 's-', linewidth=2)  
#    ax.text(1600, 54, "mod HFDI-value: %.4f" % hfdi2[i_fire[idx], j_fire[idx]])
#    ax.text(1600, 60, "CIBR-value: %.4f" % cibr[i_fire[idx], j_fire[idx]])
#    ax.text(1600, 57, "mod CIBR-value: %.4f" % cibr2[i_fire[idx], j_fire[idx]])

if saveout:
    outfile = os.path.join(outdir, "%s_spectrum_firesamples.png" % (firename,))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)

# %%
hyp.find_nearest_hyp(1200)
# Out:
# (104, 'band105', 1194.97)

# %%
ii = 0
for item in enumerate(zip(hypsc.calibratedwavelength_nm[ii:],specs_buffersample[0][ii:])):
    print(item)
# Out:
# (0, (426.81999999999999, 61.099998))
# (1, (436.99000000000001, 58.299999))
# (2, (447.17000000000002, 58.299999))
# (3, (457.33999999999997, 58.775002))
# (4, (467.51999999999998, 58.700001))
# (5, (477.69, 59.450001))
# (6, (487.87, 53.950001))
# (7, (498.04000000000002, 53.325001))
# (8, (508.22000000000003, 50.775002))
# (9, (518.38999999999999, 47.075001))
# (10, (528.57000000000005, 46.25))
# (11, (538.74000000000001, 44.825001))
# (12, (548.91999999999996, 43.700001))
# (13, (559.09000000000003, 41.849998))
# (14, (569.26999999999998, 39.125))
# (15, (579.45000000000005, 36.924999))
# (16, (589.62, 35.875))
# (17, (599.79999999999995, 34.549999))
# (18, (609.97000000000003, 34.375))
# (19, (620.14999999999998, 31.875))
# (20, (630.32000000000005, 30.549999))
# (21, (640.5, 29.825001))
# (22, (650.66999999999996, 28.9))
# (23, (660.85000000000002, 26.825001))
# (24, (671.01999999999998, 27.4))
# (25, (681.20000000000005, 26.35))
# (26, (691.37, 24.174999))
# (27, (701.54999999999995, 25.0))
# (28, (711.72000000000003, 25.5))
# (29, (721.89999999999998, 23.299999))
# (30, (732.07000000000005, 26.9))
# (31, (742.25, 30.025))
# (32, (752.42999999999995, 28.450001))
# (33, (762.60000000000002, 19.924999))
# (34, (772.77999999999997, 29.375))
# (35, (782.95000000000005, 29.450001))
# (36, (793.13, 27.25))
# (37, (803.29999999999995, 26.75))
# (38, (813.48000000000002, 22.799999))
# (39, (823.64999999999998, 21.65))
# (40, (833.83000000000004, 23.15))
# (41, (844.0, 25.525))
# (42, (854.17999999999995, 26.575001))
# (43, (864.35000000000002, 26.174999))
# (44, (874.52999999999997, 25.4))
# (45, (884.70000000000005, 24.549999))
# (46, (894.88, 21.15))
# (47, (905.04999999999995, 17.5))
# (48, (912.45000000000005, 22.6625))
# (49, (915.23000000000002, 17.200001))
# (50, (922.53999999999996, 16.725))
# (51, (925.40999999999997, 15.4))
# (52, (932.63999999999999, 6.9749999))
# (53, (942.73000000000002, 7.2375002))
# (54, (952.82000000000005, 7.4749999))
# (55, (962.90999999999997, 12.025))
# (56, (972.99000000000001, 18.012501))
# (57, (983.08000000000004, 20.950001))
# (58, (993.16999999999996, 21.862499))
# (59, (1003.3, 20.775))
# (60, (1013.3, 22.65))
# (61, (1023.4, 22.362499))
# (62, (1033.49, 21.424999))
# (63, (1043.5899999999999, 21.35))
# (64, (1053.6900000000001, 19.8125))
# (65, (1063.79, 18.65))
# (66, (1073.8900000000001, 18.424999))
# (67, (1083.99, 17.487499))
# (68, (1094.0899999999999, 15.425))
# (69, (1104.1900000000001, 11.025))
# (70, (1114.1900000000001, 4.5749998))
# (71, (1124.28, 2.2))
# (72, (1134.3800000000001, 3.4000001))
# (73, (1144.48, 3.1500001))
# (74, (1154.5799999999999, 6.3125))
# (75, (1164.6800000000001, 10.1875))
# (76, (1174.77, 11.4))
# (77, (1184.8699999999999, 10.8875))
# (78, (1194.97, 10.775))
# (79, (1205.0699999999999, 10.7375))
# (80, (1215.1700000000001, 12.1875))
# (81, (1225.1700000000001, 13.0625))
# (82, (1235.27, 13.7375))
# (83, (1245.3599999999999, 13.35))
# (84, (1255.46, 12.9625))
# (85, (1265.5599999999999, 11.825))
# (86, (1275.6600000000001, 13.15))
# (87, (1285.76, 13.0125))
# (88, (1295.8599999999999, 11.2125))
# (89, (1305.96, 9.2624998))
# (90, (1316.05, 7.7624998))
# (91, (1326.05, 5.0500002))
# (92, (1336.1500000000001, 3.6875))
# (93, (1346.25, 1.05))
# (94, (1356.3499999999999, 0.0125))
# (95, (1366.45, 0.0125))
# (96, (1376.55, 0.0125))
# (97, (1386.6500000000001, 0.0125))
# (98, (1396.74, 0.175))
# (99, (1406.8399999999999, 0.3125))
# (100, (1416.9400000000001, 0.0125))
# (101, (1426.9400000000001, 0.0125))
# (102, (1437.04, 0.125))
# (103, (1447.1400000000001, 0.41249999))
# (104, (1457.23, 0.63749999))
# (105, (1467.3299999999999, 0.34999999))
# (106, (1477.4300000000001, 0.97500002))
# (107, (1487.53, 2.25))
# (108, (1497.6300000000001, 3.8875))
# (109, (1507.73, 4.8375001))
# (110, (1517.8299999999999, 5.75))
# (111, (1527.9200000000001, 5.9749999))
# (112, (1537.9200000000001, 5.9124999))
# (113, (1548.02, 6.25))
# (114, (1558.1199999999999, 6.5999999))
# (115, (1568.22, 6.1999998))
# (116, (1578.3199999999999, 5.9499998))
# (117, (1588.4200000000001, 6.2624998))
# (118, (1598.51, 5.8125))
# (119, (1608.6099999999999, 5.875))
# (120, (1618.71, 6.4000001))
# (121, (1628.8099999999999, 6.3874998))
# (122, (1638.8099999999999, 6.3249998))
# (123, (1648.9000000000001, 6.5124998))
# (124, (1659.0, 5.9875002))
# (125, (1669.0999999999999, 5.8000002))
# (126, (1679.2, 5.8125))
# (127, (1689.3, 5.5749998))
# (128, (1699.4000000000001, 5.2750001))
# (129, (1709.5, 4.9625001))
# (130, (1719.5999999999999, 4.5250001))
# (131, (1729.7, 4.1624999))
# (132, (1739.7, 4.0))
# (133, (1749.79, 3.925))
# (134, (1759.8900000000001, 3.5250001))
# (135, (1769.99, 2.8499999))
# (136, (1780.0899999999999, 1.75))
# (137, (1790.1900000000001, 1.1625))
# (138, (1800.29, 0.4375))
# (139, (1810.3800000000001, 0.1125))
# (140, (1820.48, 0.44999999))
# (141, (1830.5799999999999, 0.36250001))
# (142, (1840.5799999999999, 0.2))
# (143, (1850.6800000000001, 0.26249999))
# (144, (1860.78, 0.0125))
# (145, (1870.8699999999999, 0.0125))
# (146, (1880.98, 0.0125))
# (147, (1891.0699999999999, 0.0125))
# (148, (1901.1700000000001, 0.0125))
# (149, (1911.27, 0.0125))
# (150, (1921.3699999999999, 0.0125))
# (151, (1931.47, 0.0125))
# (152, (1941.5699999999999, 0.0125))
# (153, (1951.5699999999999, 0.0125))
# (154, (1961.6600000000001, 0.050000001))
# (155, (1971.76, 0.67500001))
# (156, (1981.8599999999999, 1.3))
# (157, (1991.96, 1.05))
# (158, (2002.0599999999999, 0.3125))
# (159, (2012.1500000000001, 0.5625))
# (160, (2022.25, 1.3875))
# (161, (2032.3499999999999, 1.9625))
# (162, (2042.45, 1.5))
# (163, (2052.4499999999998, 0.98750001))
# (164, (2062.5500000000002, 1.5375))
# (165, (2072.6500000000001, 1.975))
# (166, (2082.75, 2.3125))
# (167, (2092.8400000000001, 2.2625))
# (168, (2102.9400000000001, 2.2625))
# (169, (2113.04, 2.325))
# (170, (2123.1399999999999, 1.975))
# (171, (2133.2399999999998, 1.85))
# (172, (2143.3400000000001, 2.4000001))
# (173, (2153.3400000000001, 2.45))
# (174, (2163.4299999999998, 1.6875))
# (175, (2173.5300000000002, 1.775))
# (176, (2183.6300000000001, 2.0625))
# (177, (2193.73, 1.95))
# (178, (2203.8299999999999, 2.0))
# (179, (2213.9299999999998, 2.175))
# (180, (2224.0300000000002, 2.0875001))
# (181, (2234.1199999999999, 2.0625))
# (182, (2244.2199999999998, 1.825))
# (183, (2254.2199999999998, 1.65))
# (184, (2264.3200000000002, 1.7125))
# (185, (2274.4200000000001, 1.8375))
# (186, (2284.52, 1.375))
# (187, (2294.6100000000001, 1.175))
# (188, (2304.71, 1.5375))
# (189, (2314.8099999999999, 1.4125))
# (190, (2324.9099999999999, 1.225))
# (191, (2335.0100000000002, 1.175))
# (192, (2345.1100000000001, 1.1))
# (193, (2355.21, 1.2125))
# (194, (2365.1999999999998, 0.71249998))
# (195, (2375.3000000000002, 0.67500001))
# (196, (2385.4000000000001, 1.4625))
# (197, (2395.5, 2.0625))

# %% [markdown]
# Start at index 98 for the last two humps of the spectrum (min wavelength: 1396.74 $\mu m$), start at index 71 for the last three (min wavelength: 1124.28 $\mu m$).

# %% [markdown]
# ## Fit spectra

# %%
from sklearn.cluster import MiniBatchKMeans, KMeans
import time

# %%
startidx = 71
startwv = 1100

# %%
specs = [spec[startidx:] for spec in specs_fire + specs_buffersample]
wav = hypsc.calibratedwavelength_nm[startidx:]
print(len(specs))
# Out:
# 694

# %%
batch_size = 20
mbk = MiniBatchKMeans(init='k-means++', n_clusters=6, batch_size=batch_size,
                      n_init=1000, max_no_improvement=1000, verbose=False)
t0 = time.time()
mbk.fit(specs)
t_mini_batch = time.time() - t0
mbk_means_labels = mbk.labels_
mbk_means_cluster_centers = mbk.cluster_centers_
mbk_means_labels_unique = np.unique(mbk_means_labels)

# %%
saveout = False
fn_template = "%s_spectrum_mbk_%s03.%s"

f, ax = plt.subplots(1, 1, figsize=(18, 12))
ax.set_xlabel("Wavelength (nm)")
ax.set_ylabel("Spectral radiance")
ax.set_xlim(startwv, 2700)
#ax.set_ylim(0, 10)
ax.set_title("%s %s fire: MiniBatch K-means cluster centers" % (fireyear, firename.capitalize()))
for idx, spec in enumerate(mbk_means_cluster_centers):
    ax.plot(wav, spec, 's-', label="cluster center nr %s" % idx)  
    plt.legend()
if saveout:
    outfile = os.path.join(outdir, fn_template % (firename, 'data', 'npz'))
    if os.path.exists(outfile):
        raise Exception("Won't overwrite %s." % outfile)
    np.savez(outfile, mbk_means_labels=mbk_means_labels, mbk_means_cluster_centers=mbk_means_cluster_centers, coords=coords)
    outfile = os.path.join(outdir, fn_template % (firename, 'clustercenters', 'png'))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)
    plt.close()

# %%
km = KMeans(init='k-means++', n_clusters=6, 
                      n_init=10, verbose=True)
t0 = time.time()
km.fit(specs)
t_km = time.time() - t0
km_means_labels = km.labels_
km_means_cluster_centers = km.cluster_centers_
km_means_labels_unique = np.unique(km_means_labels)
# Out:
# Initialization complete
# Iteration  0, inertia 8018641.130
# Iteration  1, inertia 5410024.812
# Iteration  2, inertia 5243783.016
# Iteration  3, inertia 5125837.122
# Iteration  4, inertia 5049476.141
# Iteration  5, inertia 5022334.022
# Iteration  6, inertia 5000240.334
# Iteration  7, inertia 4988230.121
# Iteration  8, inertia 4982956.644
# Iteration  9, inertia 4980949.446
# Iteration 10, inertia 4978810.788
# Iteration 11, inertia 4977877.604
# Iteration 12, inertia 4977679.038
# Converged at iteration 12
# Initialization complete
# Iteration  0, inertia 8156260.373
# Iteration  1, inertia 4980540.498
# Iteration  2, inertia 4699208.258
# Iteration  3, inertia 4695936.284
# Iteration  4, inertia 4694405.975
# Converged at iteration 4
# Initialization complete
# Iteration  0, inertia 8695694.550
# Iteration  1, inertia 5605334.113
# Iteration  2, inertia 5517697.666
# Iteration  3, inertia 5514054.144
# Converged at iteration 3
# Initialization complete
# Iteration  0, inertia 8115729.043
# Iteration  1, inertia 5100195.469
# Iteration  2, inertia 4997399.276
# Iteration  3, inertia 4966707.681
# Iteration  4, inertia 4943459.835
# Iteration  5, inertia 4930541.081
# Iteration  6, inertia 4925267.605
# Iteration  7, inertia 4923260.407
# Iteration  8, inertia 4921121.749
# Iteration  9, inertia 4920188.565
# Iteration 10, inertia 4919989.999
# Converged at iteration 10
# Initialization complete
# Iteration  0, inertia 7327821.567
# Iteration  1, inertia 5586564.189
# Iteration  2, inertia 5355575.301
# Iteration  3, inertia 5199788.035
# Iteration  4, inertia 5080651.894
# Iteration  5, inertia 5008318.286
# Iteration  6, inertia 4968842.784
# Iteration  7, inertia 4945401.084
# Iteration  8, inertia 4916728.005
# Iteration  9, inertia 4909888.638
# Iteration 10, inertia 4908346.675
# Iteration 11, inertia 4907113.635
# Iteration 12, inertia 4906891.968
# Iteration 13, inertia 4905837.490
# Iteration 14, inertia 4905164.727
# Converged at iteration 14
# Initialization complete
# Iteration  0, inertia 7342598.581
# Iteration  1, inertia 5548330.224
# Iteration  2, inertia 5408423.395
# Converged at iteration 2
# Initialization complete
# Iteration  0, inertia 8743180.995
# Iteration  1, inertia 5773344.533
# Iteration  2, inertia 5536866.345
# Iteration  3, inertia 5534065.562
# Converged at iteration 3
# Initialization complete
# Iteration  0, inertia 7960754.047
# Iteration  1, inertia 4721299.750
# Iteration  2, inertia 4660658.810
# Iteration  3, inertia 4640513.910
# Iteration  4, inertia 4623755.409
# Iteration  5, inertia 4614102.880
# Iteration  6, inertia 4611008.717
# Iteration  7, inertia 4609711.935
# Iteration  8, inertia 4607457.076
# Iteration  9, inertia 4606890.930
# Iteration 10, inertia 4606844.200
# Converged at iteration 10
# Initialization complete
# Iteration  0, inertia 9589035.153
# Iteration  1, inertia 5305111.621
# Iteration  2, inertia 4947390.020
# Iteration  3, inertia 4831063.183
# Iteration  4, inertia 4757172.454
# Iteration  5, inertia 4719447.598
# Iteration  6, inertia 4703255.871
# Iteration  7, inertia 4700209.379
# Iteration  8, inertia 4695936.284
# Iteration  9, inertia 4694405.975
# Converged at iteration 9
# Initialization complete
# Iteration  0, inertia 7165765.099
# Iteration  1, inertia 4957523.188
# Iteration  2, inertia 4701931.672
# Iteration  3, inertia 4699416.073
# Iteration  4, inertia 4697277.415
# Iteration  5, inertia 4696344.231
# Iteration  6, inertia 4696145.666
# Converged at iteration 6

# %%
saveout = False
fn_template = "%s_spectrum_km_%s02.%s"

f, ax = plt.subplots(1, 1, figsize=(18, 12))
ax.set_xlabel("Wavelength (nm)")
ax.set_ylabel("Spectral radiance")
ax.set_xlim(startwv, 2500)
#ax.set_ylim(0, 10)
ax.set_title("%s %s fire: K-means cluster centers" % (fireyear, firename.capitalize()))
for idx, spec in enumerate(km_means_cluster_centers):
    ax.plot(wav, spec, 's-', label="cluster center nr %s" % idx)  
    plt.legend()
if saveout:
    outfile = os.path.join(outdir, fn_template % (firename, 'data', 'npz'))
    if os.path.exists(outfile):
        raise Exception("Won't overwrite %s." % outfile)
    np.savez(outfile, km_means_labels=km_means_labels, km_means_cluster_centers=km_means_cluster_centers, coords=coords)
    outfile = os.path.join(outdir, fn_template % (firename, 'clustercenters', 'png'))
    plt.savefig(outfile,  bbox_inches='tight', dpi=150)
    plt.close()
